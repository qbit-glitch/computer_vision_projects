# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/notebooks/blob/main/notebooks/how-to-count-the-objects-using-ultralytics-yolo.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
#   Welcome to the Object counting using Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!</div>

# %% [markdown]
# # Object Counting using Ultralytics YOLO11
#
# This notebook serves as a starting point for [counting objects](https://docs.ultralytics.com/guides/object-counting/) in videos or live streams using the YOLO11 model.
#
# ### What is Object Counting?
#
# - Object counting with YOLO11 involves accurate identification and counting of specific objects in videos and camera streams. YOLO11 excels in real-time applications, providing efficient and precise object counting for various scenarios like crowd analysis and surveillance, thanks to its state-of-the-art algorithms and deep learning capabilities.
#
# ### Advantages of Object Counting?
#
# - **Resource Optimization**: Object counting facilitates efficient resource management by providing accurate counts, and optimizing resource allocation in applications like inventory management.
# - **Enhanced Security**: Object counting enhances security and surveillance by accurately tracking and counting entities, aiding in proactive threat detection.
# - **Informed Decision-Making**: Object counting offers valuable insights for decision-making, optimizing processes in retail, traffic management, and various other domains.

# %% [markdown]
# ### Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !pip install --upgrade ultralytics
# !pip install --upgrade torch torchvision torchaudio
# !pip show ultralytics
# Out:
# Requirement already satisfied: ultralytics in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (8.3.173)
# Requirement already satisfied: numpy>=1.23.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: filelock in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: setuptools in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torch in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (2.7.1)
# Requirement already satisfied: torchvision in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (0.22.1)
# Requirement already satisfied: torchaudio in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (2.7.1)
# Requirement already satisfied: filelock in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torch) (2025.7.0)
# Requirement already satisfied: numpy in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Name: ultralytics
# Version: 8.3.173
# Summary: Ultralytics YOLO 🚀 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://ultralytics.com
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: /Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ven2_cv/lib/python3.13/site-packages
# Requires: matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, torch, torchvision, tqdm, ultralytics-thop
# Required-by:

# %%
import ultralytics
import cv2
from ultralytics.utils.downloads import safe_download
from ultralytics import solutions

ultralytics.checks()
# Out:
# Ultralytics 8.3.173 🚀 Python-3.13.5 torch-2.7.1 CPU (Apple M4 Pro)
# Setup complete ✅ (14 CPUs, 48.0 GB RAM, 688.4/926.4 GB disk)

# %% [markdown]
# #### Some additional packages required for mac

# %% [markdown]
# ### Read the Video File
#
# - You can either read the video file directly or stream the content from an RTSP (Real-Time Streaming Protocol) source, allowing for flexible video input depending on your needs.
# - We will also set up the video writer to handle the output video writing.

# %%
# safe_download("https://github.com/ultralytics/notebooks/releases/download/v0.0.0/solutions-ci-demo.mp4")
cap = cv2.VideoCapture("cars-traffic.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH,
                                       cv2.CAP_PROP_FRAME_HEIGHT,
                                       cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("counting.avi",
                               cv2.VideoWriter_fourcc(*"mp4v"),
                               fps, (w, h))

# %% [markdown]
# ### Define Region Coordinates
#
# Here, we set the coordinates for specific regions to ensure accurate object tracking and analysis within the video or stream. This helps monitor and count objects effectively in different areas.

# %%
# Define region points
# region_points = [(20, 400), (1080, 400)]  # For line counting
region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # For rectangle region counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region counting

# %% [markdown]
# ### Initialize the ObjectCounter Class
#
# - Now, let's initialize the `ObjectCounter` class to track and count objects in each frame of the video.

# %%
from ultralytics import YOLO

model = YOLO('yolo11s.pt')
model.to('mps')
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): C2PSA(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): PSABlock(
#             (attn): Attention(
#               (qkv): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (proj): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (pe): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (ffn): Sequential(
#               (0): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#           )
#         )
#       )
#       (11): Upsample(scale_factor=2.0, mode='nearest')
#       (12): Concat()
#       (13): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (14): Upsample(scale_factor=2.0, mode='nearest')
#       (15): Concat()
#       (16): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (17): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (18): Concat()
#       (19): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (20): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (21): Concat()
#       (22): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (23): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
# Init ObjectCounter
counter = solutions.ObjectCounter(
    show=True,  # Display the output
    region=region_points,  # Pass region points
    model=model,  # model="yolo11n-obb.pt" for object counting using YOLO11 OBB model.
    classes=[0, 2],  # If you want to count specific classes i.e person and car with COCO pretrained model.
    show_in=True,  # Display in counts
    # show_out=True,  # Display out counts
    line_width=2,  # Adjust the line width for bounding boxes and text display
)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): C2PSA(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): PSABlock(
#             (attn): Attention(
#               (qkv): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (proj): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (pe): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (ffn): Sequential(
#               (0): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#           )
#         )
#       )
#       (11): Upsample(scale_factor=2.0, mode='nearest')
#       (12): Concat()
#       (13): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (14): Upsample(scale_factor=2.0, mode='nearest')
#       (15): Concat()
#       (16): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (17): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (18): Concat()
#       (19): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (20): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (21): Concat()
#       (22): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (23): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# ), 'classes': [0, 2], 'show_conf': True, 'show_labels': True, 'region': [(20, 400), (1080, 400), (1080, 360), (20, 360)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}

# %% [markdown]
# ### Process Video Frames
#
# In this step, we will process each frame of the video to detect and analyze objects. This allows for real-time tracking and counting, based on the visual data in the frames.

# %%
# Make sure codec is macOS-friendly
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS) or 30
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

video_writer = cv2.VideoWriter(
    'output.mp4', fourcc, fps, (frame_width, frame_height)
)

# Process video
while True:
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = counter(im0)  # count the objects
    frame = results.plot_im  # Make sure this matches (width, height)
    video_writer.write(results.plot_im)   # write the video frames

    # Quit if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting by user request.")
        break


cap.release()   # Release the capture
video_writer.release()
cv2.destroyAllWindows()
print("All resources released.")
# Out:
# 0: 720x1280 34.3ms
# Speed: 692.7ms track, 34.3ms solution per image at shape (1, 3, 720, 1280)
#
# 1: 720x1280 15.5ms
# Speed: 46.2ms track, 15.5ms solution per image at shape (1, 3, 720, 1280)
#
# 2: 720x1280 14.7ms
# Speed: 43.8ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# 3: 720x1280 16.5ms
# Speed: 44.9ms track, 16.5ms solution per image at shape (1, 3, 720, 1280)
#
# 4: 720x1280 14.4ms
# Speed: 43.8ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# 5: 720x1280 14.3ms
# Speed: 44.7ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 6: 720x1280 14.0ms
# Speed: 44.5ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 7: 720x1280 15.6ms
# Speed: 45.4ms track, 15.6ms solution per image at shape (1, 3, 720, 1280)
#
# 8: 720x1280 14.2ms
# Speed: 45.5ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 9: 720x1280 14.4ms
# Speed: 45.2ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# 10: 720x1280 16.0ms
# Speed: 43.7ms track, 16.0ms solution per image at shape (1, 3, 720, 1280)
#
# 11: 720x1280 16.7ms
# Speed: 43.1ms track, 16.7ms solution per image at shape (1, 3, 720, 1280)
#
# 12: 720x1280 14.3ms
# Speed: 44.5ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 13: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 14: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 15: 720x1280 14.0ms
# Speed: 43.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 16: 720x1280 13.4ms
# Speed: 44.7ms track, 13.4ms solution per image at shape (1, 3, 720, 1280)
#
# 17: 720x1280 14.2ms
# Speed: 43.9ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 18: 720x1280 14.3ms
# Speed: 44.8ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 19: 720x1280 14.0ms
# Speed: 43.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 20: 720x1280 15.5ms
# Speed: 43.9ms track, 15.5ms solution per image at shape (1, 3, 720, 1280)
#
# 21: 720x1280 14.5ms
# Speed: 45.3ms track, 14.5ms solution per image at shape (1, 3, 720, 1280)
#
# 22: 720x1280 14.5ms
# Speed: 44.3ms track, 14.5ms solution per image at shape (1, 3, 720, 1280)
#
# 23: 720x1280 14.3ms
# Speed: 45.2ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 24: 720x1280 14.3ms
# Speed: 45.4ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 25: 720x1280 14.0ms
# Speed: 43.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 26: 720x1280 14.0ms
# Speed: 45.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 27: 720x1280 14.2ms
# Speed: 45.2ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 28: 720x1280 14.0ms
# Speed: 47.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 29: 720x1280 14.1ms
# Speed: 47.7ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 30: 720x1280 14.1ms
# Speed: 47.0ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 31: 720x1280 14.4ms
# Speed: 46.8ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# 32: 720x1280 14.0ms
# Speed: 46.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 33: 720x1280 14.0ms
# Speed: 46.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 34: 720x1280 14.0ms
# Speed: 46.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 35: 720x1280 13.9ms
# Speed: 45.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 36: 720x1280 13.9ms
# Speed: 46.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 37: 720x1280 14.0ms
# Speed: 45.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 38: 720x1280 13.9ms
# Speed: 45.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 39: 720x1280 14.0ms
# Speed: 43.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 40: 720x1280 14.0ms
# Speed: 61.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 41: 720x1280 13.9ms
# Speed: 46.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 42: 720x1280 14.0ms
# Speed: 46.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 43: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 44: 720x1280 14.0ms
# Speed: 45.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 45: 720x1280 13.9ms
# Speed: 45.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 46: 720x1280 14.0ms
# Speed: 45.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 47: 720x1280 14.0ms
# Speed: 45.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 48: 720x1280 13.9ms
# Speed: 46.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 49: 720x1280 14.0ms
# Speed: 47.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 50: 720x1280 13.9ms
# Speed: 45.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 51: 720x1280 14.0ms
# Speed: 47.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 52: 720x1280 14.0ms
# Speed: 45.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 53: 720x1280 14.0ms
# Speed: 49.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 54: 720x1280 14.0ms
# Speed: 47.5ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 55: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 56: 720x1280 14.0ms
# Speed: 46.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 57: 720x1280 13.9ms
# Speed: 45.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 58: 720x1280 14.0ms
# Speed: 46.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 59: 720x1280 14.0ms
# Speed: 44.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 60: 720x1280 14.0ms
# Speed: 45.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 61: 720x1280 14.0ms
# Speed: 46.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 62: 720x1280 13.9ms
# Speed: 46.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 63: 720x1280 14.1ms
# Speed: 45.7ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 64: 720x1280 13.9ms
# Speed: 45.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 65: 720x1280 14.1ms
# Speed: 47.2ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 66: 720x1280 14.1ms
# Speed: 45.9ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 67: 720x1280 14.0ms
# Speed: 45.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 68: 720x1280 14.1ms
# Speed: 47.2ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 69: 720x1280 14.0ms
# Speed: 46.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 70: 720x1280 14.0ms
# Speed: 46.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 71: 720x1280 14.1ms
# Speed: 45.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 72: 720x1280 14.2ms
# Speed: 45.5ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 73: 720x1280 13.9ms
# Speed: 45.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 74: 720x1280 13.9ms
# Speed: 45.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 75: 720x1280 14.4ms
# Speed: 47.0ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# 76: 720x1280 14.1ms
# Speed: 49.3ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 77: 720x1280 14.0ms
# Speed: 47.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 78: 720x1280 14.3ms
# Speed: 46.8ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 79: 720x1280 14.0ms
# Speed: 45.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 80: 720x1280 13.9ms
# Speed: 45.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 81: 720x1280 14.1ms
# Speed: 43.8ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 82: 720x1280 14.1ms
# Speed: 44.5ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 83: 720x1280 14.3ms
# Speed: 46.8ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 84: 720x1280 14.0ms
# Speed: 46.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 85: 720x1280 14.2ms
# Speed: 40.4ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 86: 720x1280 14.0ms
# Speed: 41.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 87: 720x1280 13.9ms
# Speed: 40.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 88: 720x1280 14.0ms
# Speed: 42.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 89: 720x1280 14.0ms
# Speed: 41.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 90: 720x1280 13.8ms
# Speed: 42.0ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 91: 720x1280 14.1ms
# Speed: 41.8ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 92: 720x1280 14.1ms
# Speed: 41.2ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 93: 720x1280 14.1ms
# Speed: 41.4ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 94: 720x1280 13.9ms
# Speed: 40.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 95: 720x1280 14.0ms
# Speed: 41.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 96: 720x1280 14.0ms
# Speed: 41.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 97: 720x1280 14.0ms
# Speed: 42.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 98: 720x1280 14.1ms
# Speed: 41.1ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 99: 720x1280 14.0ms
# Speed: 40.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 100: 720x1280 14.0ms
# Speed: 41.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 101: 720x1280 14.0ms
# Speed: 41.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 102: 720x1280 14.1ms
# Speed: 42.9ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 103: 720x1280 13.5ms
# Speed: 41.3ms track, 13.5ms solution per image at shape (1, 3, 720, 1280)
#
# 104: 720x1280 14.0ms
# Speed: 40.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 105: 720x1280 14.0ms
# Speed: 41.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 106: 720x1280 14.0ms
# Speed: 42.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 107: 720x1280 14.0ms
# Speed: 40.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 108: 720x1280 13.9ms
# Speed: 42.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 109: 720x1280 14.1ms
# Speed: 41.8ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 110: 720x1280 13.9ms
# Speed: 42.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 111: 720x1280 14.1ms
# Speed: 41.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 112: 720x1280 13.9ms
# Speed: 41.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 113: 720x1280 14.0ms
# Speed: 41.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 114: 720x1280 14.0ms
# Speed: 41.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 115: 720x1280 14.1ms
# Speed: 41.5ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 116: 720x1280 14.0ms
# Speed: 45.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 117: 720x1280 14.1ms
# Speed: 44.5ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 118: 720x1280 14.2ms
# Speed: 44.3ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 119: 720x1280 14.2ms
# Speed: 44.7ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 120: 720x1280 14.0ms
# Speed: 45.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 121: 720x1280 14.2ms
# Speed: 44.7ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 122: 720x1280 13.9ms
# Speed: 45.0ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 123: 720x1280 14.0ms
# Speed: 44.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 124: 720x1280 14.0ms
# Speed: 45.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 125: 720x1280 14.0ms
# Speed: 45.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 126: 720x1280 14.0ms
# Speed: 44.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 127: 720x1280 14.1ms
# Speed: 43.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 128: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 129: 720x1280 13.9ms
# Speed: 43.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 130: 720x1280 14.0ms
# Speed: 44.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 131: 720x1280 13.9ms
# Speed: 44.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 132: 720x1280 14.0ms
# Speed: 44.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 133: 720x1280 14.0ms
# Speed: 44.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 134: 720x1280 13.9ms
# Speed: 45.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 135: 720x1280 13.9ms
# Speed: 43.0ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 136: 720x1280 14.0ms
# Speed: 44.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 137: 720x1280 13.9ms
# Speed: 44.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 138: 720x1280 13.9ms
# Speed: 44.0ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 139: 720x1280 13.9ms
# Speed: 43.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 140: 720x1280 13.9ms
# Speed: 44.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 141: 720x1280 14.0ms
# Speed: 44.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 142: 720x1280 13.9ms
# Speed: 44.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 143: 720x1280 13.9ms
# Speed: 44.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 144: 720x1280 14.1ms
# Speed: 44.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 145: 720x1280 14.0ms
# Speed: 44.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 146: 720x1280 14.0ms
# Speed: 44.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 147: 720x1280 14.1ms
# Speed: 43.2ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 148: 720x1280 14.0ms
# Speed: 43.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 149: 720x1280 14.1ms
# Speed: 43.8ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 150: 720x1280 14.0ms
# Speed: 44.5ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 151: 720x1280 13.9ms
# Speed: 43.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 152: 720x1280 13.9ms
# Speed: 43.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 153: 720x1280 13.6ms
# Speed: 44.2ms track, 13.6ms solution per image at shape (1, 3, 720, 1280)
#
# 154: 720x1280 14.1ms
# Speed: 44.0ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 155: 720x1280 14.1ms
# Speed: 45.0ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 156: 720x1280 14.0ms
# Speed: 44.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 157: 720x1280 14.3ms
# Speed: 62.4ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 158: 720x1280 13.9ms
# Speed: 43.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 159: 720x1280 14.2ms
# Speed: 45.1ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 160: 720x1280 13.9ms
# Speed: 44.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 161: 720x1280 13.9ms
# Speed: 44.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 162: 720x1280 13.9ms
# Speed: 42.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 163: 720x1280 13.9ms
# Speed: 41.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 164: 720x1280 13.9ms
# Speed: 41.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 165: 720x1280 13.9ms
# Speed: 41.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 166: 720x1280 13.9ms
# Speed: 40.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 167: 720x1280 13.9ms
# Speed: 40.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 168: 720x1280 14.0ms
# Speed: 41.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 169: 720x1280 14.0ms
# Speed: 41.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 170: 720x1280 13.9ms
# Speed: 40.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 171: 720x1280 13.9ms
# Speed: 42.0ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 172: 720x1280 14.1ms
# Speed: 41.5ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 173: 720x1280 14.0ms
# Speed: 41.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 174: 720x1280 13.9ms
# Speed: 42.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 175: 720x1280 14.0ms
# Speed: 41.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 176: 720x1280 13.4ms
# Speed: 42.1ms track, 13.4ms solution per image at shape (1, 3, 720, 1280)
#
# 177: 720x1280 13.9ms
# Speed: 44.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 178: 720x1280 13.9ms
# Speed: 41.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 179: 720x1280 13.9ms
# Speed: 41.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 180: 720x1280 14.0ms
# Speed: 41.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 181: 720x1280 14.0ms
# Speed: 40.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 182: 720x1280 13.8ms
# Speed: 41.7ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 183: 720x1280 13.9ms
# Speed: 41.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 184: 720x1280 14.0ms
# Speed: 42.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 185: 720x1280 13.9ms
# Speed: 40.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 186: 720x1280 14.0ms
# Speed: 40.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 187: 720x1280 14.0ms
# Speed: 41.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 188: 720x1280 13.9ms
# Speed: 42.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 189: 720x1280 14.0ms
# Speed: 41.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 190: 720x1280 13.9ms
# Speed: 41.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 191: 720x1280 14.0ms
# Speed: 41.5ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 192: 720x1280 14.0ms
# Speed: 40.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 193: 720x1280 13.9ms
# Speed: 41.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 194: 720x1280 13.9ms
# Speed: 41.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 195: 720x1280 13.9ms
# Speed: 40.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 196: 720x1280 13.9ms
# Speed: 40.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 197: 720x1280 13.9ms
# Speed: 41.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 198: 720x1280 13.9ms
# Speed: 41.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 199: 720x1280 13.9ms
# Speed: 42.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 200: 720x1280 13.9ms
# Speed: 41.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 201: 720x1280 13.9ms
# Speed: 42.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 202: 720x1280 13.9ms
# Speed: 41.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 203: 720x1280 13.8ms
# Speed: 42.1ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 204: 720x1280 13.8ms
# Speed: 41.7ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 205: 720x1280 13.9ms
# Speed: 41.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 206: 720x1280 13.2ms
# Speed: 41.6ms track, 13.2ms solution per image at shape (1, 3, 720, 1280)
#
# 207: 720x1280 13.7ms
# Speed: 41.7ms track, 13.7ms solution per image at shape (1, 3, 720, 1280)
#
# 208: 720x1280 13.9ms
# Speed: 42.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 209: 720x1280 13.9ms
# Speed: 41.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 210: 720x1280 13.9ms
# Speed: 41.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 211: 720x1280 13.8ms
# Speed: 45.8ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 212: 720x1280 13.9ms
# Speed: 43.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 213: 720x1280 14.1ms
# Speed: 43.3ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 214: 720x1280 13.9ms
# Speed: 45.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 215: 720x1280 14.0ms
# Speed: 44.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 216: 720x1280 14.1ms
# Speed: 44.7ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 217: 720x1280 13.9ms
# Speed: 43.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 218: 720x1280 14.1ms
# Speed: 44.5ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 219: 720x1280 13.9ms
# Speed: 43.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 220: 720x1280 13.8ms
# Speed: 43.7ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 221: 720x1280 14.1ms
# Speed: 43.8ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 222: 720x1280 13.9ms
# Speed: 43.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 223: 720x1280 14.0ms
# Speed: 44.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 224: 720x1280 13.9ms
# Speed: 44.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 225: 720x1280 14.0ms
# Speed: 43.5ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 226: 720x1280 13.8ms
# Speed: 43.2ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 227: 720x1280 14.0ms
# Speed: 45.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 228: 720x1280 14.0ms
# Speed: 44.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 229: 720x1280 13.9ms
# Speed: 44.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 230: 720x1280 13.8ms
# Speed: 45.0ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 231: 720x1280 14.0ms
# Speed: 45.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 232: 720x1280 13.5ms
# Speed: 44.8ms track, 13.5ms solution per image at shape (1, 3, 720, 1280)
#
# 233: 720x1280 14.0ms
# Speed: 45.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 234: 720x1280 13.9ms
# Speed: 44.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 235: 720x1280 14.1ms
# Speed: 46.7ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 236: 720x1280 13.9ms
# Speed: 45.1ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 237: 720x1280 14.0ms
# Speed: 44.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 238: 720x1280 14.1ms
# Speed: 45.2ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 239: 720x1280 14.0ms
# Speed: 42.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 240: 720x1280 14.2ms
# Speed: 44.5ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 241: 720x1280 13.9ms
# Speed: 45.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 242: 720x1280 14.0ms
# Speed: 45.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 243: 720x1280 14.1ms
# Speed: 44.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 244: 720x1280 14.0ms
# Speed: 44.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 245: 720x1280 14.0ms
# Speed: 43.9ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 246: 720x1280 13.8ms
# Speed: 44.4ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 247: 720x1280 13.9ms
# Speed: 45.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 248: 720x1280 14.0ms
# Speed: 44.1ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 249: 720x1280 13.8ms
# Speed: 45.1ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 250: 720x1280 14.1ms
# Speed: 44.5ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 251: 720x1280 13.8ms
# Speed: 45.1ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 252: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 253: 720x1280 13.8ms
# Speed: 45.8ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 254: 720x1280 14.1ms
# Speed: 44.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 255: 720x1280 13.8ms
# Speed: 43.9ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 256: 720x1280 13.9ms
# Speed: 45.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 257: 720x1280 13.9ms
# Speed: 44.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 258: 720x1280 13.8ms
# Speed: 43.0ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 259: 720x1280 13.8ms
# Speed: 41.2ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 260: 720x1280 13.8ms
# Speed: 41.7ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 261: 720x1280 13.7ms
# Speed: 40.3ms track, 13.7ms solution per image at shape (1, 3, 720, 1280)
#
# 262: 720x1280 13.8ms
# Speed: 43.3ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 263: 720x1280 13.9ms
# Speed: 41.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 264: 720x1280 13.7ms
# Speed: 40.6ms track, 13.7ms solution per image at shape (1, 3, 720, 1280)
#
# 265: 720x1280 13.8ms
# Speed: 41.8ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 266: 720x1280 13.8ms
# Speed: 42.3ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 267: 720x1280 13.9ms
# Speed: 41.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 268: 720x1280 13.9ms
# Speed: 55.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 269: 720x1280 13.8ms
# Speed: 41.6ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 270: 720x1280 13.8ms
# Speed: 41.5ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 271: 720x1280 14.2ms
# Speed: 42.1ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 272: 720x1280 13.8ms
# Speed: 41.9ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 273: 720x1280 13.9ms
# Speed: 41.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 274: 720x1280 13.9ms
# Speed: 41.0ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 275: 720x1280 14.0ms
# Speed: 41.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 276: 720x1280 13.9ms
# Speed: 41.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 277: 720x1280 14.0ms
# Speed: 42.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 278: 720x1280 13.9ms
# Speed: 40.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 279: 720x1280 13.8ms
# Speed: 40.6ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 280: 720x1280 13.9ms
# Speed: 41.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 281: 720x1280 13.9ms
# Speed: 40.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 282: 720x1280 13.8ms
# Speed: 41.9ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 283: 720x1280 13.8ms
# Speed: 40.8ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 284: 720x1280 13.9ms
# Speed: 42.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 285: 720x1280 13.8ms
# Speed: 41.5ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 286: 720x1280 13.8ms
# Speed: 41.2ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 287: 720x1280 13.8ms
# Speed: 41.6ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 288: 720x1280 13.8ms
# Speed: 41.1ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 289: 720x1280 13.9ms
# Speed: 40.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 290: 720x1280 13.9ms
# Speed: 41.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 291: 720x1280 13.9ms
# Speed: 40.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 292: 720x1280 13.9ms
# Speed: 41.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 293: 720x1280 13.9ms
# Speed: 41.0ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 294: 720x1280 13.9ms
# Speed: 40.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 295: 720x1280 13.9ms
# Speed: 40.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 296: 720x1280 13.9ms
# Speed: 42.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 297: 720x1280 13.8ms
# Speed: 41.3ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 298: 720x1280 13.8ms
# Speed: 41.5ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 299: 720x1280 13.9ms
# Speed: 41.2ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 300: 720x1280 13.9ms
# Speed: 41.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 301: 720x1280 13.9ms
# Speed: 41.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 302: 720x1280 13.9ms
# Speed: 40.9ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 303: 720x1280 6.4ms
# Speed: 40.6ms track, 6.4ms solution per image at shape (1, 3, 720, 1280)
#
# 304: 720x1280 19.6ms
# Speed: 42.1ms track, 19.6ms solution per image at shape (1, 3, 720, 1280)
#
# 305: 720x1280 13.9ms
# Speed: 42.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 306: 720x1280 14.1ms
# Speed: 43.4ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 307: 720x1280 14.1ms
# Speed: 45.3ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 308: 720x1280 14.0ms
# Speed: 44.7ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 309: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 310: 720x1280 14.0ms
# Speed: 44.8ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 311: 720x1280 13.8ms
# Speed: 44.5ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 312: 720x1280 14.1ms
# Speed: 44.8ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 313: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 314: 720x1280 13.9ms
# Speed: 43.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 315: 720x1280 13.9ms
# Speed: 44.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 316: 720x1280 14.0ms
# Speed: 44.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 317: 720x1280 13.9ms
# Speed: 43.3ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 318: 720x1280 13.8ms
# Speed: 45.1ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 319: 720x1280 13.9ms
# Speed: 44.8ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 320: 720x1280 13.8ms
# Speed: 44.1ms track, 13.8ms solution per image at shape (1, 3, 720, 1280)
#
# 321: 720x1280 13.9ms
# Speed: 45.0ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 322: 720x1280 13.9ms
# Speed: 45.6ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 323: 720x1280 14.0ms
# Speed: 45.2ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 324: 720x1280 13.9ms
# Speed: 42.5ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# 325: 720x1280 14.0ms
# Speed: 46.4ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 326: 720x1280 4.6ms
# Speed: 44.4ms track, 4.6ms solution per image at shape (1, 3, 720, 1280)
#
# 327: 720x1280 19.4ms
# Speed: 44.4ms track, 19.4ms solution per image at shape (1, 3, 720, 1280)
#
# 328: 720x1280 14.1ms
# Speed: 45.1ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 329: 720x1280 14.1ms
# Speed: 44.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 330: 720x1280 14.0ms
# Speed: 45.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 331: 720x1280 7.9ms
# Speed: 45.0ms track, 7.9ms solution per image at shape (1, 3, 720, 1280)
#
# 332: 720x1280 20.5ms
# Speed: 44.6ms track, 20.5ms solution per image at shape (1, 3, 720, 1280)
#
# 333: 720x1280 14.0ms
# Speed: 46.3ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 334: 720x1280 14.1ms
# Speed: 45.7ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 335: 720x1280 14.0ms
# Speed: 45.0ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# 336: 720x1280 8.3ms
# Speed: 45.5ms track, 8.3ms solution per image at shape (1, 3, 720, 1280)
#
# 337: 720x1280 19.7ms
# Speed: 45.6ms track, 19.7ms solution per image at shape (1, 3, 720, 1280)
#
# 338: 720x1280 21.1ms
# Speed: 46.4ms track, 21.1ms solution per image at shape (1, 3, 720, 1280)
#
# 339: 720x1280 14.2ms
# Speed: 45.4ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 340: 720x1280 14.3ms
# Speed: 46.2ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 341: 720x1280 14.1ms
# Speed: 45.7ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 342: 720x1280 14.1ms
# Speed: 44.5ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# 343: 720x1280 8.4ms
# Speed: 45.3ms track, 8.4ms solution per image at shape (1, 3, 720, 1280)
#
# 344: 720x1280 16.8ms
# Speed: 46.3ms track, 16.8ms solution per image at shape (1, 3, 720, 1280)
#
# 345: 720x1280 18.9ms
# Speed: 46.0ms track, 18.9ms solution per image at shape (1, 3, 720, 1280)
#
# 346: 720x1280 14.2ms
# Speed: 46.8ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 347: 720x1280 14.2ms
# Speed: 45.0ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# 348: 720x1280 14.3ms
# Speed: 47.6ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# 349: 720x1280 14.2ms
# Speed: 45.2ms track, 14.2ms solution per image at shape (1, 3, 720, 1280)
#
# Quitting by user request.
# All resources released.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ![Fish Counting in the Sea Using Ultralytics YOLO11](https://github.com/ultralytics/docs/releases/download/0/conveyor-belt-packets-counting.avif)

# %% [markdown]
# Crafted with 💙 by [Ultralytics](https://ultralytics.com/)
#
# 🌟 Explore and star the [Ultralytics Notebooks](https://github.com/ultralytics/notebooks/) to supercharge your AI journey! 🚀
