# %% [markdown]
# ## PARSeq Installation and Inference

# %%
print("PARSeq Installation and Inference")
# Out:
# PARSeq Installation and Inference

# %% [markdown]
# Create a python virtual environment with `python 3.10`, then activate environment in yout terminal type these commands:
#
# ```bash
# platform=cpu
# make torch-{$platform}
# pip install -r requirements/core.{$platform}.txt -e .[train,test]
# ```
#
# Then restart your jupyter notebook or python environment on which you have installed the above.

# %%
import torch
from PIL import Image
from strhub.data.module import SceneTextDataModule

# %%
# Load model and image transforms
parseq = torch.hub.load('baudm/parseq', 'parseq', pretrained=True).eval()
img_transform = SceneTextDataModule.get_transform(parseq.hparams.img_size)

# img = Image.open('/path/to/image.png').convert('RGB')
img = Image.open('/Users/qbit-glitch/Desktop/coding-projects/computer_vision_projects/ai_pipeline_license_plate_recognition/testing_images/test_img1.jpg').convert('RGB')

# Preprocess. Model expects a batch of images with shape: (B, C, H, W)
img = img_transform(img).unsqueeze(0)

logits = parseq(img)
logits.shape  # torch.Size([1, 26, 95]), 94 characters + [EOS] symbol

# Greedy decoding
pred = logits.softmax(-1)
label, confidence = parseq.tokenizer.decode(pred)
print('Decoded label = {}'.format(label[0]))
# Out:
# Using cache found in /Users/qbit-glitch/.cache/torch/hub/baudm_parseq_main
# Decoded label = RJ14UK1589
